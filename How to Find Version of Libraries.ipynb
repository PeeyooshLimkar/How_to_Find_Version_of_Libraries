# %% [markdown]
# <br>

# %% [markdown]
# # How to Find Version of Libraries

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %%
pip show pandas
# Out:
# Name: pandas
# Version: 1.5.1
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: c:\users\piyus\anaconda3\lib\site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: altair, category-encoders, cufflinks, datashader, geopandas, holoviews, hvplot, seaborn, statsmodels, streamlit, tidypandas, xarray
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# alabaster                     0.7.12
# altair                        4.2.0
# anaconda-client               1.11.0
# anaconda-navigator            2.3.2
# anaconda-project              0.11.1
# and                           66.0.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asgiref                       3.5.2
# astroid                       2.6.6
# astropy                       5.1
# asttokens                     2.0.5
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# ...

# %%
pip list | findstr pandas
# Out:
# geopandas                     0.12.2
# pandas                        1.5.1
# tidypandas                    0.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas
pandas.__version__
# Out:
# '1.4.4'

# %%
pip freeze
# Out:
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/workNote: you may need to restart the kernel to use updated packages.
#
# altair==4.2.0
# anaconda-client==1.11.0
# anaconda-navigator==2.3.2
# anaconda-project @ file:///C:/Windows/TEMP/abs_91fu4tfkih/croots/recipe/anaconda-project_1660339890874/work
# and==66.0.2
# anyio @ file:///C:/ci/anyio_1644481921011/work/dist
# appdirs==1.4.4
# argon2-cffi @ file:///opt/conda/conda-bld/argon2-cffi_1645000214183/work
# argon2-cffi-bindings @ file:///C:/ci/argon2-cffi-bindings_1644551690056/work
# arrow @ file:///C:/b/abs_b4078n3t7m/croot/arrow_1666726878744/work
# asgiref==3.5.2
# astroid @ file:///C:/ci/astroid_1628063282661/work
# astropy @ file:///C:/ci/astropy_1657719656942/work
# asttokens @ file:///opt/conda/conda-bld/asttokens_1646925590279/work
# atomicwrites==1.4.0
# attrs @ file:///opt/conda/conda-bld/attrs_1642510447205/work
# Automat @ file:///tmp/build/80754af9/automat_1600298431173/work
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ## Some Special Libraries

# %% [markdown]
# <br>

# %%
import sys

sys.version
# Out:
# '3.9.13 (main, Oct 13 2022, 21:23:06) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# <br>
